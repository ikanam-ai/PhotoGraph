# %% [markdown]
# # Проект: Анализ лиц на фотографиях из VK-альбома
# **Альбом ВКонтакте:** https://vk.com/album-130344439_305487633
#
# ## Описание проекта
# В этом проекте мы анализируем фотографии из открытых альбомов VK, извлекаем лица, получаем эмбеддинги, строим граф встреч между персонами и визуализируем результаты.

# %% [markdown]
# ## Описание датасета
# - **Источник:** фотографии из альбома VK `https://vk.com/album-130344439_305487633`
# - **photo_id** — ID фото в VK
# - **face_id** — уникальный ID лица
# - **embedding** — эмбеддинг (512-мерный вектор)
# - **bbox** — координаты лица (x, y, width, height)
# - **album_id** — ID альбома
# - **source_url** — ссылка на фото

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
from sklearn.cluster import DBSCAN
import pandas as pd
import face_recognition
import networkx as nx
from itertools import combinations
from pyvis.network import Network
import streamlit as st
import matplotlib.pyplot as plt
import streamlit.components.v1 as components
import os
import requests
import ast
# Out:
# /Users/anastasiafirsova/photo_env/lib/python3.13/site-packages/face_recognition_models/__init__.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %% [markdown]
# ## Скачивание изображений из VK
# Мы используем VK API, чтобы получить фотографии из открытого альбома.

# %%
access_token = "vk1.a.JNcse_34a53EI22HdfTWl2OKeJ57xqXwxMLzIuoB7tftRyd54Zr5ybvKBec3tWIJTkaqUYxno9RSEk86QDaNtxAj0ga9eASo85oyAK2FWW1HsXQaOfnnBj7bvGdP0PM53tdEIfzj_sMVIrT0fA946q2mW1IkDfDUCvZcZ26Anwb3R3aCC_UpRTCRkNrUmvutLBeYq_HMrVAjKYKazPiCbg"
api_version = "5.131"
owner_id = "-130344439"     
album_id = "305487633"      # id альбома VK

# Получаем список фотографий в альбоме
photos_url = (
    f"https://api.vk.com/method/photos.get?"
    f"owner_id={owner_id}&album_id={album_id}"
    f"&access_token={access_token}&v={api_version}&count=1000"
)
res = requests.get(photos_url).json()
items = res.get("response", {}).get("items", [])
os.makedirs("images", exist_ok=True)
for photo in items:
    # Берём максимальный размер (последний в списке sizes)
    photo_url = photo["sizes"][-1]["url"]
    photo_id = photo["id"]
    filename = f"images/photo_{photo_id}.jpg"
    # Скачиваем и сохраняем файл
    img_data = requests.get(photo_url).content
    with open(filename, "wb") as f:
        f.write(img_data)
    print(f"Saved {filename}")
# Out:
# Saved images/photo_457248653.jpg
# Saved images/photo_457248654.jpg
# Saved images/photo_457248655.jpg
# Saved images/photo_457248656.jpg
# Saved images/photo_457248657.jpg
# Saved images/photo_457248658.jpg
# Saved images/photo_457248659.jpg
# Saved images/photo_457248660.jpg
# Saved images/photo_457248661.jpg
# Saved images/photo_457248662.jpg
# Saved images/photo_457248663.jpg
# Saved images/photo_457248664.jpg
# Saved images/photo_457248665.jpg
# Saved images/photo_457248666.jpg
# Saved images/photo_457248667.jpg
# Saved images/photo_457248668.jpg
# Saved images/photo_457248669.jpg
# Saved images/photo_457248670.jpg
# Saved images/photo_457248671.jpg
# Saved images/photo_457248672.jpg
# Saved images/photo_457248673.jpg
# Saved images/photo_457248674.jpg
# Saved images/photo_457248675.jpg
# Saved images/photo_457248676.jpg
# Saved images/photo_457248677.jpg
# Saved images/photo_457248678.jpg
# Saved images/photo_457248679.jpg
# Saved images/photo_457248680.jpg
# Saved images/photo_457248681.jpg
# Saved images/photo_457248682.jpg
# Saved images/photo_457248683.jpg
# Saved images/photo_457248684.jpg
# Saved images/photo_457248685.jpg
# Saved images/photo_457248686.jpg
# Saved images/photo_457248687.jpg
# Saved images/photo_457248688.jpg
# Saved images/photo_457248689.jpg
# Saved images/photo_457248690.jpg
# Saved images/photo_457248691.jpg
# Saved images/photo_457248692.jpg
# Saved images/photo_457248693.jpg
# Saved images/photo_457248694.jpg
# Saved images/photo_457248695.jpg
# Saved images/photo_457248696.jpg
# Saved images/photo_457248697.jpg
# Saved images/photo_457248698.jpg
# Saved images/photo_457248699.jpg
# Saved images/photo_457248700.jpg
# Saved images/photo_457248701.jpg
# Saved images/photo_457248702.jpg
# Saved images/photo_457248703.jpg
# Saved images/photo_457248704.jpg
# Saved images/photo_457248705.jpg
# Saved images/photo_457248706.jpg
# Saved images/photo_457248707.jpg
# Saved images/photo_457248708.jpg
# Saved images/photo_457248709.jpg
# Saved images/photo_457248710.jpg
# Saved images/photo_457248711.jpg
# Saved images/photo_457248712.jpg
# Saved images/photo_457248713.jpg
# Saved images/photo_457248714.jpg
# Saved images/photo_457248715.jpg
# Saved images/photo_457248716.jpg
# Saved images/photo_457248717.jpg
# Saved images/photo_457248718.jpg
# Saved images/photo_457248719.jpg
# Saved images/photo_457248720.jpg
# Saved images/photo_457248721.jpg
# Saved images/photo_457248722.jpg
# Saved images/photo_457248723.jpg
# Saved images/photo_457248724.jpg
# Saved images/photo_457248725.jpg
# Saved images/photo_457248726.jpg
# Saved images/photo_457248727.jpg
# Saved images/photo_457248728.jpg
# Saved images/photo_457248729.jpg
# Saved images/photo_457248730.jpg
# Saved images/photo_457248731.jpg
# Saved images/photo_457248732.jpg
# Saved images/photo_457248733.jpg
# Saved images/photo_457248734.jpg
# Saved images/photo_457248735.jpg
# Saved images/photo_457248736.jpg
# Saved images/photo_457248737.jpg
# Saved images/photo_457248738.jpg
# Saved images/photo_457248739.jpg
# Saved images/photo_457248740.jpg
# Saved images/photo_457248741.jpg
# Saved images/photo_457248742.jpg
# Saved images/photo_457248743.jpg
# Saved images/photo_457248744.jpg
# Saved images/photo_457248745.jpg
# Saved images/photo_457248746.jpg
# Saved images/photo_457248747.jpg
# Saved images/photo_457248748.jpg
# Saved images/photo_457248749.jpg
# Saved images/photo_457248750.jpg
# Saved images/photo_457248751.jpg
# Saved images/photo_457248752.jpg
# Saved images/photo_457248753.jpg
# Saved images/photo_457248754.jpg
# Saved images/photo_457248755.jpg
# Saved images/photo_457248756.jpg
# Saved images/photo_457248757.jpg
# Saved images/photo_457248758.jpg
# Saved images/photo_457248759.jpg
# Saved images/photo_457248760.jpg
# Saved images/photo_457248761.jpg
# Saved images/photo_457248762.jpg
# Saved images/photo_457248763.jpg
# Saved images/photo_457248764.jpg
# Saved images/photo_457248765.jpg
# Saved images/photo_457248766.jpg
# Saved images/photo_457248767.jpg
# Saved images/photo_457248768.jpg
# Saved images/photo_457248769.jpg
# Saved images/photo_457248770.jpg
# Saved images/photo_457248771.jpg
# Saved images/photo_457248772.jpg
# Saved images/photo_457248773.jpg
# Saved images/photo_457248774.jpg
# Saved images/photo_457248775.jpg
# Saved images/photo_457248776.jpg
# Saved images/photo_457248777.jpg
# Saved images/photo_457248778.jpg
# Saved images/photo_457248779.jpg
# Saved images/photo_457248780.jpg
# Saved images/photo_457248781.jpg
# Saved images/photo_457248783.jpg
# Saved images/photo_457248784.jpg
# Saved images/photo_457248785.jpg
# Saved images/photo_457248786.jpg
# Saved images/photo_457248787.jpg
# Saved images/photo_457248788.jpg
# Saved images/photo_457248789.jpg
# Saved images/photo_457248790.jpg
# Saved images/photo_457248791.jpg
# Saved images/photo_457248792.jpg
# Saved images/photo_457248793.jpg
# Saved images/photo_457248794.jpg
# Saved images/photo_457248795.jpg
# Saved images/photo_457248796.jpg
# Saved images/photo_457248797.jpg
# Saved images/photo_457248798.jpg
# Saved images/photo_457248799.jpg
# Saved images/photo_457248800.jpg
# Saved images/photo_457248801.jpg
# Saved images/photo_457248802.jpg
# Saved images/photo_457248803.jpg
# Saved images/photo_457248804.jpg
# Saved images/photo_457248805.jpg
# Saved images/photo_457248806.jpg
# Saved images/photo_457248807.jpg
# Saved images/photo_457248808.jpg
# Saved images/photo_457248809.jpg
# Saved images/photo_457248810.jpg
# Saved images/photo_457248811.jpg
# Saved images/photo_457248812.jpg
# Saved images/photo_457248813.jpg
# Saved images/photo_457248814.jpg
# Saved images/photo_457248815.jpg
# Saved images/photo_457248816.jpg
# Saved images/photo_457248817.jpg
# Saved images/photo_457248818.jpg
# Saved images/photo_457248819.jpg
# Saved images/photo_457248820.jpg
# Saved images/photo_457248821.jpg
# Saved images/photo_457248822.jpg
# Saved images/photo_457248823.jpg
# Saved images/photo_457248824.jpg
# Saved images/photo_457248825.jpg
# Saved images/photo_457248826.jpg
# Saved images/photo_457248827.jpg
# Saved images/photo_457248828.jpg
# Saved images/photo_457248829.jpg
# Saved images/photo_457248830.jpg
# Saved images/photo_457248831.jpg
# Saved images/photo_457248832.jpg
# Saved images/photo_457248833.jpg
# Saved images/photo_457248834.jpg
# Saved images/photo_457248835.jpg
# Saved images/photo_457248836.jpg
# Saved images/photo_457248837.jpg
# Saved images/photo_457248838.jpg
# Saved images/photo_457248839.jpg
# Saved images/photo_457248840.jpg
# Saved images/photo_457248841.jpg
# Saved images/photo_457248842.jpg
# Saved images/photo_457248843.jpg
# Saved images/photo_457248844.jpg
# Saved images/photo_457248845.jpg
# Saved images/photo_457248846.jpg
# Saved images/photo_457248847.jpg
# Saved images/photo_457248848.jpg
# Saved images/photo_457248849.jpg
# Saved images/photo_457248850.jpg
# Saved images/photo_457248851.jpg
# Saved images/photo_457248852.jpg
# Saved images/photo_457248853.jpg
# Saved images/photo_457248854.jpg
# Saved images/photo_457248855.jpg
# Saved images/photo_457248856.jpg
# Saved images/photo_457248857.jpg
# Saved images/photo_457248858.jpg
# Saved images/photo_457248859.jpg
# Saved images/photo_457248860.jpg
# Saved images/photo_457248861.jpg
# Saved images/photo_457248862.jpg
# Saved images/photo_457248863.jpg
# Saved images/photo_457248864.jpg
# Saved images/photo_457248865.jpg
# Saved images/photo_457248866.jpg
# Saved images/photo_457248867.jpg
# Saved images/photo_457248868.jpg
# Saved images/photo_457248869.jpg
# Saved images/photo_457248870.jpg
# Saved images/photo_457248871.jpg
# Saved images/photo_457248872.jpg
# Saved images/photo_457248873.jpg
# Saved images/photo_457248874.jpg
# Saved images/photo_457248875.jpg
# Saved images/photo_457248876.jpg
# Saved images/photo_457248877.jpg
# Saved images/photo_457248878.jpg
# Saved images/photo_457248879.jpg
# Saved images/photo_457248880.jpg
# Saved images/photo_457248881.jpg
# Saved images/photo_457248882.jpg
# Saved images/photo_457248883.jpg
# Saved images/photo_457248884.jpg
# Saved images/photo_457248885.jpg
# Saved images/photo_457248886.jpg
# Saved images/photo_457248887.jpg
# Saved images/photo_457248888.jpg
# Saved images/photo_457248889.jpg
# Saved images/photo_457248890.jpg
# Saved images/photo_457248891.jpg
# Saved images/photo_457248892.jpg
# Saved images/photo_457248893.jpg
# Saved images/photo_457248894.jpg
# Saved images/photo_457248895.jpg
# Saved images/photo_457248896.jpg
# Saved images/photo_457248897.jpg
# Saved images/photo_457248899.jpg
# Saved images/photo_457248900.jpg
# Saved images/photo_457248901.jpg
# Saved images/photo_457248902.jpg
# Saved images/photo_457248903.jpg
# Saved images/photo_457248904.jpg
# Saved images/photo_457248905.jpg
# Saved images/photo_457248906.jpg
# Saved images/photo_457248907.jpg
# Saved images/photo_457248908.jpg
# Saved images/photo_457248909.jpg
# Saved images/photo_457248910.jpg
# Saved images/photo_457248911.jpg
# Saved images/photo_457248912.jpg
# Saved images/photo_457248913.jpg
# Saved images/photo_457248914.jpg
# Saved images/photo_457248915.jpg
# Saved images/photo_457248916.jpg
# Saved images/photo_457248917.jpg
# Saved images/photo_457248918.jpg
# Saved images/photo_457248919.jpg
# Saved images/photo_457248920.jpg
# Saved images/photo_457248921.jpg
# Saved images/photo_457248922.jpg
# Saved images/photo_457248923.jpg
# Saved images/photo_457248924.jpg
# Saved images/photo_457248925.jpg
# Saved images/photo_457248926.jpg
# Saved images/photo_457248927.jpg
# Saved images/photo_457248928.jpg
# Saved images/photo_457248929.jpg
# Saved images/photo_457248930.jpg
# Saved images/photo_457248931.jpg
# Saved images/photo_457248932.jpg
# Saved images/photo_457248933.jpg
# Saved images/photo_457248934.jpg
# Saved images/photo_457248935.jpg
# Saved images/photo_457248936.jpg
# Saved images/photo_457248937.jpg
# Saved images/photo_457248938.jpg
# Saved images/photo_457248939.jpg
# Saved images/photo_457248940.jpg
# Saved images/photo_457248941.jpg
# Saved images/photo_457248942.jpg
# Saved images/photo_457248943.jpg
# Saved images/photo_457248944.jpg
# Saved images/photo_457248945.jpg
# Saved images/photo_457248946.jpg
# Saved images/photo_457248947.jpg
# Saved images/photo_457248948.jpg
# Saved images/photo_457248950.jpg
# Saved images/photo_457248951.jpg
# Saved images/photo_457248952.jpg
# Saved images/photo_457248953.jpg
# Saved images/photo_457248954.jpg
# Saved images/photo_457248955.jpg
# Saved images/photo_457248956.jpg
# Saved images/photo_457248957.jpg
# Saved images/photo_457248958.jpg
# Saved images/photo_457248959.jpg
# Saved images/photo_457248960.jpg
# Saved images/photo_457248961.jpg
# Saved images/photo_457248962.jpg
# Saved images/photo_457248963.jpg
# Saved images/photo_457248964.jpg
# Saved images/photo_457248965.jpg
# Saved images/photo_457248966.jpg
# Saved images/photo_457248967.jpg
# Saved images/photo_457248968.jpg
# Saved images/photo_457248969.jpg
# Saved images/photo_457248970.jpg
# Saved images/photo_457248971.jpg
# Saved images/photo_457248972.jpg
# Saved images/photo_457248973.jpg
# Saved images/photo_457248974.jpg
# Saved images/photo_457248975.jpg
# Saved images/photo_457248976.jpg
# Saved images/photo_457248977.jpg
# Saved images/photo_457248978.jpg
# Saved images/photo_457248979.jpg
# Saved images/photo_457248980.jpg
# Saved images/photo_457248981.jpg
# Saved images/photo_457248982.jpg
# Saved images/photo_457248983.jpg
# Saved images/photo_457248984.jpg
# Saved images/photo_457248985.jpg
# Saved images/photo_457248986.jpg
# Saved images/photo_457248987.jpg
# Saved images/photo_457248988.jpg
# Saved images/photo_457248989.jpg
# Saved images/photo_457248990.jpg
# Saved images/photo_457248991.jpg
# Saved images/photo_457248992.jpg
# Saved images/photo_457248993.jpg
# Saved images/photo_457248994.jpg
# Saved images/photo_457248995.jpg
# Saved images/photo_457248996.jpg
# Saved images/photo_457248997.jpg
# Saved images/photo_457248998.jpg
# Saved images/photo_457248999.jpg
# Saved images/photo_457249000.jpg
# Saved images/photo_457249001.jpg
# Saved images/photo_457249002.jpg
# Saved images/photo_457249003.jpg
# Saved images/photo_457249004.jpg
# Saved images/photo_457249005.jpg
# Saved images/photo_457249006.jpg
# Saved images/photo_457249007.jpg
# Saved images/photo_457249008.jpg
# Saved images/photo_457249009.jpg
# Saved images/photo_457249010.jpg
# Saved images/photo_457249011.jpg
# Saved images/photo_457249012.jpg
# Saved images/photo_457249013.jpg
# Saved images/photo_457249014.jpg
# Saved images/photo_457249015.jpg
# Saved images/photo_457249016.jpg
# Saved images/photo_457249017.jpg
# Saved images/photo_457249018.jpg
# Saved images/photo_457249019.jpg
# Saved images/photo_457249020.jpg
# Saved images/photo_457249021.jpg
# Saved images/photo_457249022.jpg
# Saved images/photo_457249023.jpg
# Saved images/photo_457249024.jpg
# Saved images/photo_457249025.jpg
# Saved images/photo_457249026.jpg
# Saved images/photo_457249027.jpg
# Saved images/photo_457249028.jpg
# Saved images/photo_457249029.jpg
# Saved images/photo_457249030.jpg
# Saved images/photo_457249031.jpg
# Saved images/photo_457249032.jpg
# Saved images/photo_457249033.jpg
# Saved images/photo_457249034.jpg
# Saved images/photo_457249035.jpg
# Saved images/photo_457249036.jpg
# Saved images/photo_457249037.jpg
# Saved images/photo_457249038.jpg
# Saved images/photo_457249039.jpg
# Saved images/photo_457249040.jpg
# Saved images/photo_457249041.jpg
# Saved images/photo_457249042.jpg
# Saved images/photo_457249043.jpg
# Saved images/photo_457249044.jpg
# Saved images/photo_457249045.jpg
# Saved images/photo_457249046.jpg
# Saved images/photo_457249047.jpg
# Saved images/photo_457249048.jpg
# Saved images/photo_457249049.jpg
# Saved images/photo_457249050.jpg
# Saved images/photo_457249051.jpg
# Saved images/photo_457249052.jpg
# Saved images/photo_457249053.jpg
# Saved images/photo_457249054.jpg
# Saved images/photo_457249055.jpg
# Saved images/photo_457249056.jpg
# Saved images/photo_457249057.jpg
# Saved images/photo_457249058.jpg
# Saved images/photo_457249059.jpg
# Saved images/photo_457249060.jpg
# Saved images/photo_457249061.jpg
# Saved images/photo_457249062.jpg
# Saved images/photo_457249063.jpg
# Saved images/photo_457249064.jpg
# Saved images/photo_457249065.jpg
# Saved images/photo_457249066.jpg
# Saved images/photo_457249067.jpg
# Saved images/photo_457249068.jpg
# Saved images/photo_457249069.jpg
# Saved images/photo_457249070.jpg
# Saved images/photo_457249071.jpg
# Saved images/photo_457249072.jpg
# Saved images/photo_457249073.jpg
# Saved images/photo_457249074.jpg
# Saved images/photo_457249075.jpg
# Saved images/photo_457249076.jpg
# Saved images/photo_457249077.jpg
# Saved images/photo_457249078.jpg
# Saved images/photo_457249079.jpg
# Saved images/photo_457249080.jpg
# Saved images/photo_457249081.jpg
# Saved images/photo_457249082.jpg
# Saved images/photo_457249083.jpg
# Saved images/photo_457249084.jpg
# Saved images/photo_457249085.jpg
# Saved images/photo_457249086.jpg
# Saved images/photo_457249087.jpg
# Saved images/photo_457249088.jpg
# Saved images/photo_457249089.jpg
# Saved images/photo_457249090.jpg
# Saved images/photo_457249091.jpg
# Saved images/photo_457249092.jpg
# Saved images/photo_457249093.jpg
# Saved images/photo_457249094.jpg
# Saved images/photo_457249095.jpg
# Saved images/photo_457249096.jpg
# Saved images/photo_457249097.jpg
# Saved images/photo_457249098.jpg
# Saved images/photo_457249099.jpg
# Saved images/photo_457249100.jpg
# Saved images/photo_457249101.jpg
# Saved images/photo_457249102.jpg
# Saved images/photo_457249103.jpg
# Saved images/photo_457249104.jpg
# Saved images/photo_457249105.jpg
# Saved images/photo_457249106.jpg
# Saved images/photo_457249107.jpg
# Saved images/photo_457249108.jpg
# Saved images/photo_457249109.jpg
# Saved images/photo_457249110.jpg
# Saved images/photo_457249111.jpg
# Saved images/photo_457249112.jpg
# Saved images/photo_457249113.jpg
# Saved images/photo_457249114.jpg
# Saved images/photo_457249115.jpg
# Saved images/photo_457249116.jpg
# Saved images/photo_457249117.jpg
# Saved images/photo_457249118.jpg
# Saved images/photo_457249119.jpg
# Saved images/photo_457249120.jpg
# Saved images/photo_457249121.jpg
# Saved images/photo_457249122.jpg
# Saved images/photo_457249123.jpg
# Saved images/photo_457249124.jpg
# Saved images/photo_457249125.jpg
# Saved images/photo_457249126.jpg
# Saved images/photo_457249127.jpg
# Saved images/photo_457249128.jpg
# Saved images/photo_457249129.jpg
# Saved images/photo_457249130.jpg
# Saved images/photo_457249131.jpg
# Saved images/photo_457249132.jpg
# Saved images/photo_457249133.jpg
# Saved images/photo_457249134.jpg
# Saved images/photo_457249135.jpg
# Saved images/photo_457249136.jpg
# Saved images/photo_457249137.jpg
# Saved images/photo_457249138.jpg
# Saved images/photo_457249139.jpg
# Saved images/photo_457249140.jpg
# Saved images/photo_457249141.jpg
# Saved images/photo_457249142.jpg
# Saved images/photo_457249143.jpg
# Saved images/photo_457249144.jpg
# Saved images/photo_457249145.jpg
# Saved images/photo_457249146.jpg
# Saved images/photo_457249147.jpg
# Saved images/photo_457249148.jpg
# Saved images/photo_457249149.jpg
# Saved images/photo_457249150.jpg
# Saved images/photo_457249151.jpg
# Saved images/photo_457249152.jpg
# Saved images/photo_457249153.jpg
# Saved images/photo_457249154.jpg
# Saved images/photo_457249155.jpg
# Saved images/photo_457249156.jpg
# Saved images/photo_457249157.jpg
# Saved images/photo_457249158.jpg
# Saved images/photo_457249159.jpg
# Saved images/photo_457249160.jpg
# Saved images/photo_457249162.jpg
# Saved images/photo_457249163.jpg
# Saved images/photo_457249164.jpg
# Saved images/photo_457249165.jpg

# %% [markdown]
# ## Распознавание лиц

# %%
data = []
face_id_counter = 0

for image_file in os.listdir("images"):
    image = face_recognition.load_image_file(f"images/{image_file}")
    # Находим все лица: возвращается список bbox (top, right, bottom, left)
    face_locations = face_recognition.face_locations(image)
    # Получаем 128-мерные эмбеддинги для найденных лиц
    face_encodings = face_recognition.face_encodings(image, face_locations)
    photo_id = int(image_file.split("_")[1].split(".")[0])  # извлечение ID из имени
    
    for loc, emb in zip(face_locations, face_encodings):
        (top, right, bottom, left) = loc
        face_id_counter += 1
        data.append({
            "photo_id": photo_id,
            "face_id": face_id_counter,
            "embedding": emb.tolist(),
            "bbox": (left, top, right-left, bottom-top),
            "album_id": album_id,
            "source_url": np.nan  # сделаем это позже
        })

# Сохраняем результат в CSV
df = pd.DataFrame(data)
df.to_csv("faces.csv", index=False)
print(f"Обнаружено {len(df)} лиц на {len(items)} фотографиях")

# %% [markdown]
# ## Кластеризация лиц и генерация person_id

# %%
encodings = np.vstack(df["embedding"].to_numpy())  # матрица N×128
clt = DBSCAN(metric="euclidean", eps=0.42, min_samples=2).fit(encodings)
labels = clt.labels_  # label - идентификатор кластера (человека)
df["person_id"] = labels
num_persons = len(set(labels))
print(f"Найдено {num_persons} уникальных людей")

# %%
group_id = "-130344439"
photo_url_shab = "https://vk.com/photo{}_{}"  # group_id, photo_id

# Добавляем album_id
df["album_id"] = album_id

# Формируем source_url
df["source_url"] = df["photo_id"].apply(
    lambda pid: photo_url_shab.format(group_id, pid)
)

# %% [markdown]
# ## Данные

# %%
df.head()

# %% [markdown]
# #### При использовании данного способа появляется person_id = -1:
# #### Это плохо распознанные, размытые лица (например, фото с самим посвящением, где  лица прикрыты), эти объекты считаются шумом и не относятся ни к одному кластеру

# %%
df_clean = df[df["person_id"] != -1].copy()
df = df_clean.copy()

# %% [markdown]
# ## Построение графа по co-occurrence

# %%
G = nx.Graph()
# Добавляем узлы (по person_id)
G.add_nodes_from(labels)
# Для каждой фотографии: получаем list уникальных person_id
for pid in df["photo_id"].unique():
    persons = set(df[df["photo_id"] == pid]["person_id"])
    for u, v in combinations(persons, 2):
        if G.has_edge(u, v):
            G[u][v]["weight"] += 1
        else:
            G.add_edge(u, v, weight=1)

# Сохраняем ребра графа в таблицу
edges = [(u, v, G[u][v]["weight"]) for u, v in G.edges()]
edges_df = pd.DataFrame(edges, columns=["person_id_1", "person_id_2", "cooccurrence_count"])
edges_df.to_csv("graph_edges.csv", index=False)
graph_edges = pd.read_csv('graph_edges.csv')
graph_edges

# %%
print("Всего обнаруженных лиц:", len(df))
print("Всего обнаруженных людей:", df['person_id'].nunique())
print("Топ-5 активных пользователей:")
print(df["person_id"].value_counts().head(5))

# %% [markdown]
# ## Визуализация графа (NetworkX)

# %%
edges_graph_edgesf = pd.read_csv("graph_edges.csv")

G = nx.Graph()
for _, row in graph_edges.iterrows():
    G.add_edge(row["person_id_1"], row["person_id_2"], weight=row["cooccurrence_count"])

node_size = [100 + 50 * G.degree(n) for n in G.nodes()]
edge_width = [G[u][v]['weight'] for u, v in G.edges()]
pos = nx.spring_layout(G, k=0.5, iterations=50)

plt.figure(figsize=(12, 12))
nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color='skyblue', alpha=0.8)
nx.draw_networkx_edges(G, pos, width=edge_width, edge_color='gray', alpha=0.5)
nx.draw_networkx_labels(G, pos, font_size=8)

plt.title("Социальный граф: встречи по фотографиям")
plt.axis("off")
plt.tight_layout()

# %% [markdown]
# ## Визуализация HTML

# %%
G = nx.Graph()
for _, row in edges_df.iterrows():
    u = str(int(row["person_id_1"]))
    v = str(int(row["person_id_2"]))
    weight = int(row["cooccurrence_count"]) 
    G.add_edge(u, v, weight=weight)

# %%
net = Network(height='600px', width='100%', notebook=True)

# %%
net = Network(height='600px', width='100%', notebook=True)
net.from_nx(G)
net.show("vk_faces.html")
